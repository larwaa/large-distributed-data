# %% [markdown]
# # Introduction
# This notebook performs the tasks in the exercise

# %%
from geolife import Geolife
from database import Database
from environs import Env

# %% [markdown]
# ## Set up the database
#
# Load environment variables

# %%
env = Env()
env.read_env(".env")

# %%
database = Database(
    host=env.str("DB_HOST"),
    port=env.int("DB_PORT"),
    user=env.str("DB_USER"),
    password=env.str("DB_PASSWORD"),
    database=env.str("DB_DATABASE")
)

# %% [markdown]
# ## Set up migrator

# %%
geolife = Geolife(database)

# %% [markdown]
# ### Run migrations

# %%
geolife.migrate()

# %% [markdown]
# ### (OPTIONALLY) Wipe the DB
# 🚨 THIS WILL WIPE ALL DATA IN THE TABLES 🚨

# %%
geolife.wipe()

# %% [markdown]
# ### Seed the database with data from the data set

# %%
geolife.seed()
