# %% [markdown]
# # Introduction
# This notebook performs the tasks in the exercise

# %%
# %load_ext autoreload
# %autoreload 2

# %%
from migrator import Migrator
from database import Database
from environs import Env
import tasks as t
import pandas as pd

# %% [markdown]
# ## Part 1
# Setting up and seeding the database.

# %%
env = Env()
env.read_env(".env")

# %%
database = Database(
    host=env.str("DB_HOST"),
    port=3307,
    user=env.str("DB_USER"),
    password=env.str("DB_PASSWORD"),
    database=env.str("DB_DATABASE")
)
# Out:
# Connected to: 8.1.0
# You are connected to the database: ('mysql',)
# -----------------------------------------------

# %% [markdown]
# ### Create tables

# %%
migrator = Migrator(database, 2500)

# %%
migrator.migrate()
# Out:
# --------------------------------Starting migrate--------------------------------
# Found migration files:  ['001_users.sql', '002_activities.sql', '003_trackpoints.sql']
# Running migration:   001_users.sql       ✅
# Running migration:   002_activities.sql  ✅
# Running migration:   003_trackpoints.sql ✅
# -------------------------Finished migrate in 58.146 ms--------------------------

# %% [markdown]
# ### (DANGER) Wipe the DB
# 🚨 THIS WILL WIPE ALL DATA IN THE TABLES 🚨

# %%
migrator.wipe()
# Out:
# ---------------------------------Starting wipe----------------------------------
# Wiping TrackPoints
# Wiping Activities
# Wiping Users
# --------------------------Finished wipe in 1134.808 ms--------------------------

# %% [markdown]
# ### Seed Database from Data Set

# %%
migrator.seed_users()
# Out:
# ------------------------------Starting seed_users-------------------------------
# Seeded [(182,)] Users
# ------------------------Finished seed_users in 16.647 ms------------------------

# %%
migrator.seed_activities()
# Out:
# ----------------------------Starting seed_activities----------------------------
# Generating seed data for user: 135	✅
# Generating seed data for user: 132	✅
# Generating seed data for user: 104	✅
# Generating seed data for user: 103	✅
# Generating seed data for user: 168	✅
# Generating seed data for user: 157	✅
# Generating seed data for user: 150	✅
# Generating seed data for user: 159	✅
# Generating seed data for user: 166	✅
# Generating seed data for user: 161	✅
# Generating seed data for user: 102	✅
# Generating seed data for user: 105	✅
# Generating seed data for user: 133	✅
# Generating seed data for user: 134	✅
# Generating seed data for user: 160	✅
# Generating seed data for user: 158	✅
# Generating seed data for user: 167	✅
# Generating seed data for user: 151	✅
# Generating seed data for user: 169	✅
# Generating seed data for user: 156	✅
# Generating seed data for user: 024	✅
# Generating seed data for user: 023	✅
# Generating seed data for user: 015	✅
# Generating seed data for user: 012	✅
# Generating seed data for user: 079	✅
# Generating seed data for user: 046	✅
# Generating seed data for user: 041	✅
# Generating seed data for user: 048	✅
# Generating seed data for user: 077	✅
# Generating seed data for user: 083	✅
# Generating seed data for user: 084	✅
# Generating seed data for user: 070	✅
# Generating seed data for user: 013	✅
# Generating seed data for user: 014	✅
# Generating seed data for user: 022	✅
# Generating seed data for user: 025	✅
# Generating seed data for user: 071	✅
# Generating seed data for user: 085	✅
# Generating seed data for user: 049	✅
# Generating seed data for user: 082	✅
# Generating seed data for user: 076	✅
# Generating seed data for user: 040	✅
# Generating seed data for user: 078	✅
# Generating seed data for user: 047	✅
# Generating seed data for user: 065	✅
# Generating seed data for user: 091	✅
# Generating seed data for user: 096	✅
# Generating seed data for user: 062	✅
# Generating seed data for user: 054	✅
# Generating seed data for user: 053	✅
# Generating seed data for user: 098	✅
# Generating seed data for user: 038	✅
# Generating seed data for user: 007	✅
# Generating seed data for user: 000	✅
# Generating seed data for user: 009	✅
# Generating seed data for user: 036	✅
# Generating seed data for user: 031	✅
# Generating seed data for user: 052	✅
# Generating seed data for user: 099	✅
# Generating seed data for user: 055	✅
# Generating seed data for user: 063	✅
# Generating seed data for user: 097	✅
# Generating seed data for user: 090	✅
# Generating seed data for user: 064	✅
# Generating seed data for user: 030	✅
# Generating seed data for user: 008	✅
# Generating seed data for user: 037	✅
# Generating seed data for user: 001	✅
# Generating seed data for user: 039	✅
# Generating seed data for user: 006	✅
# Generating seed data for user: 174	✅
# Generating seed data for user: 180	✅
# Generating seed data for user: 173	✅
# Generating seed data for user: 145	✅
# Generating seed data for user: 142	✅
# Generating seed data for user: 129	✅
# Generating seed data for user: 116	✅
# Generating seed data for user: 111	✅
# Generating seed data for user: 118	✅
# Generating seed data for user: 127	✅
# Generating seed data for user: 120	✅
# Generating seed data for user: 143	✅
# Generating seed data for user: 144	✅
# Generating seed data for user: 172	✅
# Generating seed data for user: 181	✅
# Generating seed data for user: 175	✅
# Generating seed data for user: 121	✅
# Generating seed data for user: 119	✅
# Generating seed data for user: 126	✅
# Generating seed data for user: 110	✅
# Generating seed data for user: 128	✅
# Generating seed data for user: 117	✅
# Generating seed data for user: 153	✅
# Generating seed data for user: 154	✅
# Generating seed data for user: 162	✅
# Generating seed data for user: 165	✅
# Generating seed data for user: 131	✅
# Generating seed data for user: 136	✅
# Generating seed data for user: 109	✅
# Generating seed data for user: 100	✅
# Generating seed data for user: 107	✅
# Generating seed data for user: 138	✅
# Generating seed data for user: 164	✅
# Generating seed data for user: 163	✅
# Generating seed data for user: 155	✅
# Generating seed data for user: 152	✅
# Generating seed data for user: 106	✅
# Generating seed data for user: 139	✅
# Generating seed data for user: 101	✅
# Generating seed data for user: 137	✅
# Generating seed data for user: 108	✅
# Generating seed data for user: 130	✅
# Generating seed data for user: 089	✅
# Generating seed data for user: 042	✅
# Generating seed data for user: 045	✅
# Generating seed data for user: 087	✅
# Generating seed data for user: 073	✅
# Generating seed data for user: 074	✅
# Generating seed data for user: 080	✅
# Generating seed data for user: 020	✅
# Generating seed data for user: 027	✅
# Generating seed data for user: 018	✅
# Generating seed data for user: 011	✅
# Generating seed data for user: 016	✅
# Generating seed data for user: 029	✅
# Generating seed data for user: 081	✅
# Generating seed data for user: 075	✅
# Generating seed data for user: 072	✅
# Generating seed data for user: 086	✅
# Generating seed data for user: 044	✅
# Generating seed data for user: 088	✅
# Generating seed data for user: 043	✅
# Generating seed data for user: 017	✅
# Generating seed data for user: 028	✅
# Generating seed data for user: 010	✅
# Generating seed data for user: 026	✅
# Generating seed data for user: 019	✅
# Generating seed data for user: 021	✅
# Generating seed data for user: 003	✅
# Generating seed data for user: 004	✅
# Generating seed data for user: 032	✅
# Generating seed data for user: 035	✅
# Generating seed data for user: 095	✅
# Generating seed data for user: 061	✅
# Generating seed data for user: 066	✅
# Generating seed data for user: 092	✅
# Generating seed data for user: 059	✅
# Generating seed data for user: 050	✅
# Generating seed data for user: 057	✅
# Generating seed data for user: 068	✅
# Generating seed data for user: 034	✅
# Generating seed data for user: 033	✅
# Generating seed data for user: 005	✅
# Generating seed data for user: 002	✅
# Generating seed data for user: 056	✅
# Generating seed data for user: 069	✅
# Generating seed data for user: 051	✅
# Generating seed data for user: 093	✅
# Generating seed data for user: 067	✅
# Generating seed data for user: 058	✅
# Generating seed data for user: 060	✅
# Generating seed data for user: 094	✅
# Generating seed data for user: 112	✅
# Generating seed data for user: 115	✅
# Generating seed data for user: 123	✅
# Generating seed data for user: 124	✅
# Generating seed data for user: 170	✅
# Generating seed data for user: 177	✅
# Generating seed data for user: 148	✅
# Generating seed data for user: 141	✅
# Generating seed data for user: 146	✅
# Generating seed data for user: 179	✅
# Generating seed data for user: 125	✅
# Generating seed data for user: 122	✅
# Generating seed data for user: 114	✅
# Generating seed data for user: 113	✅
# Generating seed data for user: 147	✅
# Generating seed data for user: 178	✅
# Generating seed data for user: 140	✅
# Generating seed data for user: 176	✅
# Generating seed data for user: 149	✅
# Generating seed data for user: 171	✅
# Seeded 16048 Activities
# --------------------Finished seed_activities in 22517.616 ms--------------------

# %%
migrator.seed_track_points()
# Out:
# ---------------------------Starting seed_track_points---------------------------
# Generating seed data for user: 135	✅
# Generating seed data for user: 132	✅
# Generating seed data for user: 104	✅
# Generating seed data for user: 103	✅
# Generating seed data for user: 168	✅
# Generating seed data for user: 157	✅
# Generating seed data for user: 150	✅
# Generating seed data for user: 159	✅
# Generating seed data for user: 166	✅
# Generating seed data for user: 161	✅
# Generating seed data for user: 102	✅
# Generating seed data for user: 105	✅
# Generating seed data for user: 133	✅
# Generating seed data for user: 134	✅
# Generating seed data for user: 160	✅
# Generating seed data for user: 158	✅
# Generating seed data for user: 167	✅
# Generating seed data for user: 151	✅
# Generating seed data for user: 169	✅
# Generating seed data for user: 156	✅
# Generating seed data for user: 024	✅
# Generating seed data for user: 023	✅
# Generating seed data for user: 015	✅
# Generating seed data for user: 012	✅
# Generating seed data for user: 079	✅
# Generating seed data for user: 046	✅
# Generating seed data for user: 041	✅
# Generating seed data for user: 048	✅
# Generating seed data for user: 077	✅
# Generating seed data for user: 083	✅
# Generating seed data for user: 084	✅
# Generating seed data for user: 070	✅
# Generating seed data for user: 013	✅
# Generating seed data for user: 014	✅
# Generating seed data for user: 022	✅
# Generating seed data for user: 025	✅
# Generating seed data for user: 071	✅
# Generating seed data for user: 085	✅
# Generating seed data for user: 049	✅
# Generating seed data for user: 082	✅
# Generating seed data for user: 076	✅
# Generating seed data for user: 040	✅
# Generating seed data for user: 078	✅
# Generating seed data for user: 047	✅
# Generating seed data for user: 065	✅
# Generating seed data for user: 091	✅
# Generating seed data for user: 096	✅
# Generating seed data for user: 062	✅
# Generating seed data for user: 054	✅
# Generating seed data for user: 053	✅
# Generating seed data for user: 098	✅
# Generating seed data for user: 038	✅
# Generating seed data for user: 007	✅
# Generating seed data for user: 000	✅
# Generating seed data for user: 009	✅
# Generating seed data for user: 036	✅
# Generating seed data for user: 031	✅
# Generating seed data for user: 052	✅
# Generating seed data for user: 099	✅
# Generating seed data for user: 055	✅
# Generating seed data for user: 063	✅
# Generating seed data for user: 097	✅
# Generating seed data for user: 090	✅
# Generating seed data for user: 064	✅
# Generating seed data for user: 030	✅
# Generating seed data for user: 008	✅
# Generating seed data for user: 037	✅
# Generating seed data for user: 001	✅
# Generating seed data for user: 039	✅
# Generating seed data for user: 006	✅
# Generating seed data for user: 174	✅
# Generating seed data for user: 180	✅
# Generating seed data for user: 173	✅
# Generating seed data for user: 145	✅
# Generating seed data for user: 142	✅
# Generating seed data for user: 129	✅
# Generating seed data for user: 116	✅
# Generating seed data for user: 111	✅
# Generating seed data for user: 118	✅
# Generating seed data for user: 127	✅
# Generating seed data for user: 120	✅
# Generating seed data for user: 143	✅
# Generating seed data for user: 144	✅
# Generating seed data for user: 172	✅
# Generating seed data for user: 181	✅
# Generating seed data for user: 175	✅
# Generating seed data for user: 121	✅
# Generating seed data for user: 119	✅
# Generating seed data for user: 126	✅
# Generating seed data for user: 110	✅
# Generating seed data for user: 128	✅
# Generating seed data for user: 117	✅
# Generating seed data for user: 153	✅
# Generating seed data for user: 154	✅
# Generating seed data for user: 162	✅
# Generating seed data for user: 165	✅
# Generating seed data for user: 131	✅
# Generating seed data for user: 136	✅
# Generating seed data for user: 109	✅
# Generating seed data for user: 100	✅
# Generating seed data for user: 107	✅
# Generating seed data for user: 138	✅
# Generating seed data for user: 164	✅
# Generating seed data for user: 163	✅
# Generating seed data for user: 155	✅
# Generating seed data for user: 152	✅
# Generating seed data for user: 106	✅
# Generating seed data for user: 139	✅
# Generating seed data for user: 101	✅
# Generating seed data for user: 137	✅
# Generating seed data for user: 108	✅
# Generating seed data for user: 130	✅
# Generating seed data for user: 089	✅
# Generating seed data for user: 042	✅
# Generating seed data for user: 045	✅
# Generating seed data for user: 087	✅
# Generating seed data for user: 073	✅
# Generating seed data for user: 074	✅
# Generating seed data for user: 080	✅
# Generating seed data for user: 020	✅
# Generating seed data for user: 027	✅
# Generating seed data for user: 018	✅
# Generating seed data for user: 011	✅
# Generating seed data for user: 016	✅
# Generating seed data for user: 029	✅
# Generating seed data for user: 081	✅
# Generating seed data for user: 075	✅
# Generating seed data for user: 072	✅
# Generating seed data for user: 086	✅
# Generating seed data for user: 044	✅
# Generating seed data for user: 088	✅
# Generating seed data for user: 043	✅
# Generating seed data for user: 017	✅
# Generating seed data for user: 028	✅
# Generating seed data for user: 010	✅
# Generating seed data for user: 026	✅
# Generating seed data for user: 019	✅
# Generating seed data for user: 021	✅
# Generating seed data for user: 003	✅
# Generating seed data for user: 004	✅
# Generating seed data for user: 032	✅
# Generating seed data for user: 035	✅
# Generating seed data for user: 095	✅
# Generating seed data for user: 061	✅
# Generating seed data for user: 066	✅
# Generating seed data for user: 092	✅
# Generating seed data for user: 059	✅
# Generating seed data for user: 050	✅
# Generating seed data for user: 057	✅
# Generating seed data for user: 068	✅
# Generating seed data for user: 034	✅
# Generating seed data for user: 033	✅
# Generating seed data for user: 005	✅
# Generating seed data for user: 002	✅
# Generating seed data for user: 056	✅
# Generating seed data for user: 069	✅
# Generating seed data for user: 051	✅
# Generating seed data for user: 093	✅
# Generating seed data for user: 067	✅
# Generating seed data for user: 058	✅
# Generating seed data for user: 060	✅
# Generating seed data for user: 094	✅
# Generating seed data for user: 112	✅
# Generating seed data for user: 115	✅
# Generating seed data for user: 123	✅
# Generating seed data for user: 124	✅
# Generating seed data for user: 170	✅
# Generating seed data for user: 177	✅
# Generating seed data for user: 148	✅
# Generating seed data for user: 141	✅
# Generating seed data for user: 146	✅
# Generating seed data for user: 179	✅
# Generating seed data for user: 125	✅
# Generating seed data for user: 122	✅
# Generating seed data for user: 114	✅
# Generating seed data for user: 113	✅
# Generating seed data for user: 147	✅
# Generating seed data for user: 178	✅
# Generating seed data for user: 140	✅
# Generating seed data for user: 176	✅
# Generating seed data for user: 149	✅
# Generating seed data for user: 171	✅
# 262144
# [('135-20090103012134', 'Point(39.974294 116.399741)', '492', '39816.0566435185', '2009-01-03 01:21:34'), ('135-20090103012134', 'Point(39.974292 116.399592)', '492', '39816.0566550926', '2009-01-03 01:21:35'), ('135-20090103012134', 'Point(39.974309 116.399523)', '492', '39816.0566666667', '2009-01-03 01:21:36'), ('135-20090103012134', 'Point(39.97432 116.399588)', '492', '39816.0566898148', '2009-01-03 01:21:38'), ('135-20090103012134', 'Point(39.974365 116.39973)', '491', '39816.0567013889', '2009-01-03 01:21:39'), ('135-20090103012134', 'Point(39.974391 116.399782)', '491', '39816.0567361111', '2009-01-03 01:21:42'), ('135-20090103012134', 'Point(39.974426 116.399735)', '491', '39816.0567824074', '2009-01-03 01:21:46'), ('135-20090103012134', 'Point(39.974458 116.3997)', '491', '39816.0568402778', '2009-01-03 01:21:51'), ('135-20090103012134', 'Point(39.974491 116.399732)', '490', '39816.0568981481', '2009-01-03 01:21:56'), ('135-20090103012134', 'Point(39.97453 116.399758)', '489', '39816.0569560185', '2009-01-03 01:22:01'), ('135-20090103012134', 'Point(39.974577 116.399745)', '490', '39816.0569907407', '2009-01-03 01:22:04'), ('135-20090103012134', 'Point(39.974623 116.399731)', '491', '39816.057025463', '2009-01-03 01:22:07'), ('135-20090103012134', 'Point(39.974666 116.399713)', '491', '39816.0570601852', '2009-01-03 01:22:10'), ('135-20090103012134', 'Point(39.9747 116.399755)', '491', '39816.0570949074', '2009-01-03 01:22:13'), ('135-20090103012134', 'Point(39.974732 116.399838)', '491', '39816.0571412037', '2009-01-03 01:22:17'), ('135-20090103012134', 'Point(39.97473 116.399909)', '491', '39816.0571527778', '2009-01-03 01:22:18'), ('135-20090103012134', 'Point(39.974728 116.399982)', '491', '39816.0571643518', '2009-01-03 01:22:19'), ('135-20090103012134', 'Point(39.974731 116.400052)', '491', '39816.0571875', '2009-01-03 01:22:21'), ('135-20090103012134', 'Point(39.97473 116.400143)', '491', '39816.0571990741', '2009-01-03 01:22:22'), ('135-20090103012134', 'Point(39.974737 116.400205)', '491', '39816.0572222222', '2009-01-03 01:22:24')]
# Seeding batch: 0 of 36	✅
# Seeding batch: 1 of 36	✅
# Seeding batch: 2 of 36	✅
# Seeding batch: 3 of 36	✅
# Seeding batch: 4 of 36	✅
# Seeding batch: 5 of 36	✅
# Seeding batch: 6 of 36	✅
# Seeding batch: 7 of 36	✅
# Seeding batch: 8 of 36	✅
# Seeding batch: 9 of 36	✅
# Seeding batch: 10 of 36	✅
# Seeding batch: 11 of 36	✅
# Seeding batch: 12 of 36	✅
# Seeding batch: 13 of 36	✅
# Seeding batch: 14 of 36	✅
# Seeding batch: 15 of 36	✅
# Seeding batch: 16 of 36	✅
# Seeding batch: 17 of 36	✅
# Seeding batch: 18 of 36	✅
# Seeding batch: 19 of 36	✅
# Seeding batch: 20 of 36	✅
# Seeding batch: 21 of 36	✅
# Seeding batch: 22 of 36	✅
# Seeding batch: 23 of 36	✅
# Seeding batch: 24 of 36	✅
# Seeding batch: 25 of 36	✅
# Seeding batch: 26 of 36	✅
# Seeding batch: 27 of 36	✅
# Seeding batch: 28 of 36	✅
# Seeding batch: 29 of 36	✅
# Seeding batch: 30 of 36	✅
# Seeding batch: 31 of 36	✅
# Seeding batch: 32 of 36	✅
# Seeding batch: 33 of 36	✅
# Seeding batch: 34 of 36	✅
# Seeding batch: 35 of 36	✅
# Seeding batch: 36 of 36	✅
# Seeded [(9681756,)] TrackPoints
# ------------------Finished seed_track_points in 255735.785 ms-------------------

# %%
migrator.create_indices()
# Out:
# ----------------------------Starting create_indices-----------------------------
# Executing statement
#  ALTER TABLE TrackPoints ADD INDEX datetime_idx (datetime); ✅
# --------------------Finished create_indices in 12093.948 ms---------------------

# %% [markdown]
# ## Part 2

# %%
tasks = t.Task(database)

# %% [markdown]
# ### Task 1

# %%
tasks.task1()

# %% [markdown]
# ### Task 2

# %%
tasks.task2()

# %% [markdown]
# ### Task 3

# %%
tasks.task3()

# %% [markdown]
# ### Task 4

# %%
tasks.task4()

# %% [markdown]
# ### Task 5

# %%
tasks.task5()

# %% [markdown]
# ### Task 7

# %%
tasks.task7a()

# %%
tasks.task7b()

# %% [markdown]
# ### Task 8

# %%
tasks.task8()

# %%
# query = """
#     SELECT DISTINCT left.user_id AS UserID1, right.user_id AS UserID2
#     FROM full AS left
#     INNER JOIN full AS right
#         ON left.user_id != right.user_id
#         AND left.datetime <= right.datetime
#         AND MBRContains(ST_BUFFER(left.geom, 50), right.geom)
#         AND TIME_TO_SEC(TIMEDIFF(right.datetime, left.datetime)) <= 30
# """



query = """
SELECT DISTINCT p1.user_id as UserID1, p2.user_id AS UserID2
FROM full AS p1
INNER JOIN full AS p2
    ON p1.user_id != p2.user_id
LIMIT 10
"""

database.query(query)

# %%
database.cursor.fetchall()

# %%
left_table = """
    CREATE TEMPORARY TABLE p1 AS
        SELECT u.id as user_id, tp.datetime as datetime, tp.geom as geom
        FROM TrackPoints as tp
        INNER JOIN Activities as a
            ON a.id = tp.activity_id
        INNER JOIN Users as u
            on u.id = a.user_id
"""
database.query(left_table)

# %%
right_table = """
    CREATE TEMPORARY TABLE p2 AS
        SELECT u.id as user_id, tp.datetime as datetime, tp.geom as geom
        FROM TrackPoints as tp
        INNER JOIN Activities as a
            ON a.id = tp.activity_id
        INNER JOIN Users as u
            on u.id = a.user_id
"""
database.query(right_table)

# %%
query = """
SELECT DISTINCT a1.user_id, a2.user_id
FROM Activities a1
JOIN TrackPoints tp1 ON a1.id = tp1.activity_id
JOIN Activities a2 ON a1.user_id != a2.user_id
JOIN TrackPoints tp2 ON a2.id = tp2.activity_id
WHERE a1.start_datetime <= a2.end_datetime
AND a1.end_datetime >= a2.start_datetime
AND ST_Distance_Sphere(tp1.geom, tp2.geom) <= 50
AND ABS(TIMESTAMPDIFF(SECOND, tp1.datetime, tp2.datetime)) <= 30
"""

database.query(query)

# %%
query = """
WITH user_pairs AS (
    SELECT DISTINCT a1.user_id AS user_id1, a2.user_id AS user_id2
    FROM Activities a1
    JOIN Activities a2 ON a1.id < a2.id
        AND TIME_TO_SEC(TIMEDIFF(a2.start_datetime, a1.end_datetime)) <= 30
        AND TIME_TO_SEC(TIMEDIFF(a1.start_datetime, a2.end_datetime)) <= 30
        AND a1.user_id < a2.user_id
)
SELECT DISTINCT user_id
FROM (
    SELECT user_id1 AS user_id FROM user_pairs
    UNION
    SELECT user_id2 FROM user_pairs
) AS user_ids;
"""

database.query(query)
# Out:
# Running statement:
#
# WITH user_pairs AS (
#     SELECT DISTINCT a1.user_id AS user_id1, a2.user_id AS user_id2
#     FROM Activities a1
#     JOIN Activities a2 ON a1.id < a2.id
#         AND TIME_TO_SEC(TIMEDIFF(a2.start_datetime, a1.end_datetime)) <= 30
#         AND TIME_TO_SEC(TIMEDIFF(a1.start_datetime, a2.end_datetime)) <= 30
#         AND a1.user_id < a2.user_id
# )
# SELECT DISTINCT user_id
# FROM (
#     SELECT user_id1 AS user_id FROM user_pairs
#     UNION
#     SELECT user_id2 FROM user_pairs
# ) AS user_ids;
#
# Query Finished
#     user_id
# 0       000
# 1       001
# 2       002
# 3       003
# 4       004
# ..      ...
# 142     166
# 143     171
# 144     152
# 145     139
# 146     168
#
# [147 rows x 1 columns]

# %%
query = """
WITH user_pairs AS (
    SELECT DISTINCT a1.user_id AS user_id1, a2.user_id AS user_id2
    FROM Activities a1
    JOIN Activities a2 ON a1.id < a2.id
        AND TIME_TO_SEC(TIMEDIFF(a2.start_datetime, a1.end_datetime)) <= 30
        AND TIME_TO_SEC(TIMEDIFF(a1.start_datetime, a2.end_datetime)) <= 30
        AND a1.user_id < a2.user_id
        JOIN TrackPoints p1 ON p1.activity_id = a1.id
)
SELECT DISTINCT user_id
FROM (
    SELECT user_id1 AS user_id FROM user_pairs
    UNION
    SELECT user_id2 FROM user_pairs
) AS user_ids;
"""

database.query(query)
# Out:
# Running statement:
#
# WITH user_pairs AS (
#     SELECT DISTINCT a1.user_id AS user_id1, a2.user_id AS user_id2
#     FROM Activities a1
#     JOIN Activities a2 ON a1.id < a2.id
#         AND TIME_TO_SEC(TIMEDIFF(a2.start_datetime, a1.end_datetime)) <= 30
#         AND TIME_TO_SEC(TIMEDIFF(a1.start_datetime, a2.end_datetime)) <= 30
#         AND a1.user_id < a2.user_id
#         JOIN TrackPoints p1 ON p1.activity_id = a1.id
# )
# SELECT DISTINCT user_id
# FROM (
#     SELECT user_id1 AS user_id FROM user_pairs
#     UNION
#     SELECT user_id2 FROM user_pairs
# ) AS user_ids;
#
# Query Finished
#     user_id
# 0       000
# 1       001
# 2       002
# 3       003
# 4       004
# ..      ...
# 142     166
# 143     171
# 144     152
# 145     139
# 146     168
#
# [147 rows x 1 columns]

# %%
query = """
WITH user_pairs AS (
    SELECT DISTINCT a1.user_id AS user_id1, a2.user_id AS user_id2
    FROM Activities a1
    JOIN Activities a2 ON a1.id < a2.id
        AND TIME_TO_SEC(TIMEDIFF(a2.start_datetime, a1.end_datetime)) <= 30
        AND TIME_TO_SEC(TIMEDIFF(a1.start_datetime, a2.end_datetime)) <= 30
        AND a1.user_id < a2.user_id
        JOIN TrackPoints p2 ON p2.activity_id = a2.id
)
SELECT DISTINCT user_id
FROM (
    SELECT user_id1 AS user_id FROM user_pairs
    UNION
    SELECT user_id2 FROM user_pairs
) AS user_ids;
"""

database.query(query)
# Out:
# Running statement:
#
# WITH user_pairs AS (
#     SELECT DISTINCT a1.user_id AS user_id1, a2.user_id AS user_id2
#     FROM Activities a1
#     JOIN Activities a2 ON a1.id < a2.id
#         AND TIME_TO_SEC(TIMEDIFF(a2.start_datetime, a1.end_datetime)) <= 30
#         AND TIME_TO_SEC(TIMEDIFF(a1.start_datetime, a2.end_datetime)) <= 30
#         AND a1.user_id < a2.user_id
#         JOIN TrackPoints p2 ON p2.activity_id = a2.id
# )
# SELECT DISTINCT user_id
# FROM (
#     SELECT user_id1 AS user_id FROM user_pairs
#     UNION
#     SELECT user_id2 FROM user_pairs
# ) AS user_ids;
#
# Query Finished
#     user_id
# 0       000
# 1       001
# 2       002
# 3       003
# 4       004
# ..      ...
# 142     166
# 143     171
# 144     152
# 145     139
# 146     168
#
# [147 rows x 1 columns]

# %%
query = """
WITH user_pairs AS (
    SELECT DISTINCT a1.user_id AS user_id1, a2.user_id AS user_id2
    FROM Activities a1
    JOIN Activities a2 ON a1.id < a2.id
        AND TIME_TO_SEC(TIMEDIFF(a2.start_datetime, a1.end_datetime)) <= 30
        AND TIME_TO_SEC(TIMEDIFF(a1.start_datetime, a2.end_datetime)) <= 30
        AND a1.user_id < a2.user_id
    JOIN TrackPoints p1 ON p1.activity_id = a1.id
    JOIN TrackPoints p2 ON p2.activity_id = a2.id
)
SELECT DISTINCT user_id
FROM (
    SELECT user_id1 AS user_id FROM user_pairs
    UNION
    SELECT user_id2 FROM user_pairs
) AS user_ids;
"""

database.query(query)
# Out:
# Running statement:
#
# WITH user_pairs AS (
#     SELECT DISTINCT a1.user_id AS user_id1, a2.user_id AS user_id2
#     FROM Activities a1
#     JOIN Activities a2 ON a1.id < a2.id
#         AND TIME_TO_SEC(TIMEDIFF(a2.start_datetime, a1.end_datetime)) <= 30
#         AND TIME_TO_SEC(TIMEDIFF(a1.start_datetime, a2.end_datetime)) <= 30
#         AND a1.user_id < a2.user_id
#     JOIN TrackPoints p1 ON p1.activity_id = a1.id
#     JOIN TrackPoints p2 ON p2.activity_id = a2.id
# )
# SELECT DISTINCT user_id
# FROM (
#     SELECT user_id1 AS user_id FROM user_pairs
#     UNION
#     SELECT user_id2 FROM user_pairs
# ) AS user_ids;
#
# Query Finished
#     user_id
# 0       000
# 1       001
# 2       002
# 3       003
# 4       004
# ..      ...
# 142     166
# 143     171
# 144     152
# 145     139
# 146     168
#
# [147 rows x 1 columns]

# %%
query = """
WITH user_pairs AS (
    SELECT DISTINCT a1.user_id AS user_id1, a2.user_id AS user_id2
    FROM Activities a1
    -- Make a combination of all activities
    JOIN Activities a2 ON a1.id < a2.id
        -- We restrict the search space to activities that overlap with a 30 second margin
        -- to limit the number of track point comparisons that we have to perform.
        -- Activities that do not overlap within at least a 30 second margin
        -- should not contain track points that are within 30 seconds of each other.
        AND TIME_TO_SEC(TIMEDIFF(a2.start_datetime, a1.end_datetime)) <= 30
        AND TIME_TO_SEC(TIMEDIFF(a1.start_datetime, a2.end_datetime)) <= 30
        -- Avoid comparing a user to themselves
        AND a1.user_id < a2.user_id
    -- Join in the track points on the two sets of activities
    JOIN TrackPoints p1 ON p1.activity_id = a1.id
    JOIN TrackPoints p2 ON p2.activity_id = a2.id
    -- Then, after restricting the search space, we check for
    -- track points that are close both in time
    WHERE ABS(TIME_TO_SEC(TIMEDIFF(p1.datetime, p2.datetime))) <= 30
    -- and in space
    AND ST_Distance_Sphere(p1.geom, p2.geom) <= 50
)
-- Finally, we select the list of distinct user_ids of users
-- who have been near other users in space and time
SELECT DISTINCT user_id
FROM (
    -- Combine the two columns of user ID pairs into a single column of user IDs
    -- to find the total count of unique users who have been near others
    SELECT user_id1 AS user_id FROM user_pairs
    UNION
    SELECT user_id2 FROM user_pairs
) AS user_ids
-- Order the results by ascending ID
ORDER BY user_id ASC;
"""

database.query(query)
# Out:
# Running statement:
#
# WITH user_pairs AS (
#     SELECT DISTINCT a1.user_id AS user_id1, a2.user_id AS user_id2
#     FROM Activities a1
#     JOIN Activities a2 ON a1.id < a2.id
#         -- We restrict the search space to activities that overlap with a 30 second margin
#         -- to limit the number of track point comparisons that we have to perform.
#         AND TIME_TO_SEC(TIMEDIFF(a2.start_datetime, a1.end_datetime)) <= 30
#         AND TIME_TO_SEC(TIMEDIFF(a1.start_datetime, a2.end_datetime)) <= 30
#         -- Avoid comparing a user to themselves
#         AND a1.user_id < a2.user_id
#     JOIN TrackPoints p1 ON p1.activity_id = a1.id
#     JOIN TrackPoints p2 ON p2.activity_id = a2.id
#     -- Then, after restricting the search space, we check for
#     -- track points that are close both in time and space
#     WHERE ABS(TIME_TO_SEC(TIMEDIFF(p1.datetime, p2.datetime))) <= 30
#     AND ST_Distance_Sphere(p1.geom, p2.geom) <= 50
# )
# -- Finally, we select the list of distinct user_ids of users
# -- who have been near other users in space and time
# SELECT DISTINCT user_id
# FROM (
#     SELECT user_id1 AS user_id FROM user_pairs
#     UNION
#     SELECT user_id2 FROM user_pairs
# ) AS user_ids
# ORDER BY user_id ASC;
#
# Query Finished
#     user_id
# 0       000
# 1       001
# 2       003
# 3       004
# 4       005
# ..      ...
# 116     173
# 117     174
# 118     175
# 119     176
# 120     179
#
# [121 rows x 1 columns]

# %%
query = """
WITH user_pairs AS (
    SELECT DISTINCT a1.user_id AS user_id1, a2.user_id AS user_id2
    FROM Activities a1
    JOIN Activities a2 ON a1.id < a2.id
        -- We restrict the search space to activities that overlap with a 30 second margin
        -- to limit the number of track point comparisons that we have to perform.
        AND TIME_TO_SEC(TIMEDIFF(a2.start_datetime, a1.end_datetime)) <= 30
        AND TIME_TO_SEC(TIMEDIFF(a1.start_datetime, a2.end_datetime)) <= 30
        -- Avoid comparing a user to themselves
        AND a1.user_id < a2.user_id
    JOIN TrackPoints p1 ON p1.activity_id = a1.id
    JOIN TrackPoints p2 ON p2.activity_id = a2.id
    WHERE ABS(TIME_TO_SEC(TIMEDIFF(p1.datetime, p2.datetime))) <= 30
)
SELECT DISTINCT user_id
FROM (
    SELECT user_id1 AS user_id FROM user_pairs
    UNION
    SELECT user_id2 FROM user_pairs
) AS user_ids;
"""

database.query(query)

# %%
query = """
SELECT DISTINCT p1.id, p2.id
FROM Activities a1
JOIN Activities a2 ON a1.id < a2.id
    AND TIME_TO_SEC(TIMEDIFF(a2.start_datetime, a1.end_datetime)) <= 30
    AND TIME_TO_SEC(TIMEDIFF(a1.start_datetime, a2.end_datetime)) <= 30
    AND a1.user_id < a2.user_id
JOIN TrackPoints p1 ON p1.activity_id = a1.id
JOIN TrackPoints p2 ON p2.activity_id = a2.id
"""

database.query(query)
# Out:
# Running statement:
#
# SELECT DISTINCT p1.id, p2.id
# FROM Activities a1
# JOIN Activities a2 ON a1.id < a2.id
#     AND TIME_TO_SEC(TIMEDIFF(a2.start_datetime, a1.end_datetime)) <= 30
#     AND TIME_TO_SEC(TIMEDIFF(a1.start_datetime, a2.end_datetime)) <= 30
#     AND a1.user_id < a2.user_id
# JOIN TrackPoints p1 ON p1.activity_id = a1.id
# JOIN TrackPoints p2 ON p2.activity_id = a2.id
#
# Query Finished
#                 id       id
# 0              911  1063368
# 1              911  1063369
# 2              911  1063370
# 3              911  1063371
# 4              911  1063372
# ...            ...      ...
# 213598906  1962424   688266
# 213598907  1962424   688267
# 213598908  1962424   688268
# 213598909  1962424   688269
# 213598910  1962424   688270
#
# [213598911 rows x 2 columns]

# %%
task_8_result = _

# %%
task_8_result
# Out:
#     user_id
# 0       000
# 1       001
# 2       003
# 3       004
# 4       005
# ..      ...
# 116     173
# 117     174
# 118     175
# 119     176
# 120     179
#
# [121 rows x 1 columns]

# %%
task_8_result.all()
# Out:
# user_id    True
# dtype: bool

# %%
with pd.option_context("display.max_rows", None):
    display(task_8_result)
# Out:
#     user_id
# 0       000
# 1       001
# 2       003
# 3       004
# 4       005
# 5       006
# 6       007
# 7       008
# 8       009
# 9       010
# 10      011
# 11      012
# 12      013
# 13      014
# 14      015
# 15      016
# 16      017
# 17      018
# 18      019
# 19      020
# 20      022
# 21      023
# 22      024
# 23      025
# 24      028
# 25      029
# 26      030
# 27      032
# 28      034
# 29      035
# 30      036
# 31      037
# 32      038
# 33      039
# 34      041
# 35      042
# 36      043
# 37      044
# 38      045
# 39      046
# 40      047
# 41      051
# 42      052
# 43      055
# 44      056
# 45      057
# 46      058
# 47      059
# 48      061
# 49      062
# 50      064
# 51      067
# 52      068
# 53      069
# 54      070
# 55      071
# 56      073
# 57      074
# 58      075
# 59      076
# 60      078
# 61      081
# 62      082
# 63      083
# 64      084
# 65      085
# 66      087
# 67      088
# 68      089
# 69      091
# 70      092
# 71      093
# 72      094
# 73      095
# 74      096
# 75      100
# 76      101
# 77      102
# 78      104
# 79      105
# 80      106
# 81      108
# 82      109
# 83      110
# 84      111
# 85      112
# 86      113
# 87      114
# 88      115
# 89      116
# 90      117
# 91      124
# 92      125
# 93      126
# 94      127
# 95      128
# 96      129
# 97      134
# 98      136
# 99      139
# 100     140
# 101     142
# 102     144
# 103     150
# 104     153
# 105     155
# 106     157
# 107     159
# 108     161
# 109     162
# 110     163
# 111     164
# 112     165
# 113     167
# 114     169
# 115     170
# 116     173
# 117     174
# 118     175
# 119     176
# 120     179

# %%
track_points_of_interest = database.query(
    """
        SELECT id
        FROM TrackPoints
        WHERE activity_id IN (
            SELECT a1.id AS id
            FROM Activities a1
            WHERE EXISTS (
                SELECT 1
                FROM Activities a2
                WHERE a2.start_datetime <= a1.end_datetime + INTERVAL 30 SECOND
                AND a2.end_datetime >= a1.start_datetime - INTERVAL 30 SECOND
                AND a1.id < id
                AND a1.user_Id < user_id
            )
        )
        ORDER BY id;
    """
)
# Out:
# Running statement:
#
#         SELECT id, activity_id, datetime, ST_LATITUDE(geom) as latitude, ST_LONGITUDE(geom) AS longitude
#         FROM TrackPoints
#         WHERE activity_id IN (
#             SELECT a1.id AS id
#             FROM Activities a1
#             WHERE EXISTS (
#                 SELECT 1
#                 FROM Activities a2
#                 WHERE a2.start_datetime <= a1.end_datetime + INTERVAL 30 SECOND
#                 AND a2.end_datetime >= a1.start_datetime - INTERVAL 30 SECOND
#                 AND a1.id < id
#                 AND a1.user_Id < user_id
#             )
#         )
#         ORDER BY id;
#
# Query Finished

# %%
track_points_of_interest
# Out:
#               id         activity_id            datetime   latitude  \
# 0              1  135-20090103012134 2009-01-03 01:21:34  39.974294
# 1              2  135-20090103012134 2009-01-03 01:21:35  39.974292
# 2              3  135-20090103012134 2009-01-03 01:21:36  39.974309
# 3              4  135-20090103012134 2009-01-03 01:21:38  39.974320
# 4              5  135-20090103012134 2009-01-03 01:21:39  39.974365
# ...          ...                 ...                 ...        ...
# 5927774  9681391  176-20071208013029 2007-12-08 03:13:54  39.971000
# 5927775  9681392  176-20071208013029 2007-12-08 03:15:01  39.971100
# 5927776  9681393  176-20071208013029 2007-12-08 03:15:54  39.970817
# 5927777  9681394  176-20071208013029 2007-12-08 03:16:57  39.970867
# 5927778  9681395  176-20071208013029 2007-12-08 03:17:35  39.970983
#
#           longitude
# 0        116.399741
# 1        116.399592
# 2        116.399523
# 3        116.399588
# 4        116.399730
# ...             ...
# 5927774  116.304200
# 5927775  116.304933
# 5927776  116.304250
# 5927777  116.303250
# 5927778  116.305600
#
# [5927779 rows x 5 columns]

# %%
import multiprocessing
from multi import get_id_pairs

# %%
processes = 11
pool = multiprocessing.Pool(processes)
batch_size = track_points_of_interest.shape[0] // processes

# %%
def get_batch_ids(batch_idx, batch_size, df, database):
    current_batch = df.iloc[batch_size * batch_idx: batch_size * (batch_idx + 1)]
    first, last = current_batch.iloc[[0, -1]]["id"]
    return database, first, last, first, last

batch_input = [get_batch_ids(i, batch_size, track_points_of_interest, database) for i in range(processes)]

# %%
results = pool.map(get_id_pairs, batch_input)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /Users/larswaage/Code/large-distributed-data/src/test_notebook copy.ipynb Cell 55 line 1
# ----> <a href='vscode-notebook-cell:/Users/larswaage/Code/large-distributed-data/src/test_notebook%20copy.ipynb#Y120sZmlsZQ%3D%3D?line=0'>1</a> results = pool.map(make_get_id_pairs(database), batch_input)
#
# File ~/.pyenv/versions/3.11.5/lib/python3.11/multiprocessing/pool.py:367, in Pool.map(self, func, iterable, chunksize)
#     362 def map(self, func, iterable, chunksize=None):
#     363     '''
#     364     Apply `func` to each element in `iterable`, collecting the results
#     365     in a list that is returned.
#     366     '''
# --> 367     return self._map_async(func, iterable, mapstar, chunksize).get()
#
# File ~/.pyenv/versions/3.11.5/lib/python3.11/multiprocessing/pool.py:774, in ApplyResult.get(self, timeout)
#     772     return self._value
#     773 else:
# --> 774     raise self._value
#
# File ~/.pyenv/versions/3.11.5/lib/python3.11/multiprocessing/pool.py:540, in Pool._handle_tasks(taskqueue, put, outqueue, pool, cache)
#     538     break
#     539 try:
# --> 540     put(task)
#     541 except Exception as e:
#     542     job, idx = task[:2]
#
# File ~/.pyenv/versions/3.11.5/lib/python3.11/multiprocessing/connection.py:205, in _ConnectionBase.send(self, obj)
#     203 self._check_closed()
#     204 self._check_writable()
# --> 205 self._send_bytes(_ForkingPickler.dumps(obj))
#
# File ~/.pyenv/versions/3.11.5/lib/python3.11/multiprocessing/reduction.py:51, in ForkingPickler.dumps(cls, obj, protocol)
#      48 @classmethod
#      49 def dumps(cls, obj, protocol=None):
#      50     buf = io.BytesIO()
# ---> 51     cls(buf, protocol).dump(obj)
#      52     return buf.getbuffer()
#
# AttributeError: Can't pickle local object 'make_get_id_pairs.<locals>.get_id_pairs'

# %%
batch_input
# Out:
# [(1, 1085465, 1, 1085465),
#  (1085466, 1677769, 1085466, 1677769),
#  (1677770, 2374860, 1677770, 2374860),
#  (2374861, 3067020, 2374861, 3067020),
#  (3067021, 3652122, 3067021, 3652122),
#  (3652123, 4597806, 3652123, 4597806),
#  (4597807, 6632630, 4597807, 6632630),
#  (6632631, 7535069, 6632631, 7535069),
#  (7535070, 8107145, 7535070, 8107145),
#  (8107146, 8771418, 8107146, 8771418),
#  (8771419, 9681395, 8771419, 9681395)]

# %%
batch_size
# Out:
# 493981

# %%
get_id_pairs((3021481, 3021482, 3021481, 3021482))
# Out:
# Running statement:
#
#         WITH acts AS (
#             SELECT a1.id AS id, a1.user_id AS user_id
#             FROM Activities a1
#             WHERE EXISTS (
#                 SELECT 1
#                 FROM Activities a2
#                 WHERE a2.start_datetime <= a1.end_datetime + INTERVAL 30 SECOND
#                 AND a2.end_datetime >= a1.start_datetime - INTERVAL 30 SECOND
#                 AND a1.id < id
#                 AND a1.user_Id < user_id
#             )
#         ),
#         batch_track_points AS (
#             SELECT id, activity_id, datetime, geom
#             FROM TrackPoints
#             WHERE activity_id IN (
#                 SELECT id
#                 FROM acts
#             )
#             AND id BETWEEN %s AND %s
#         ),
#         track_points_of_interest AS (
#             SELECT id, activity_id, datetime, geom
#             FROM TrackPoints
#             WHERE activity_id IN (
#                 SELECT id
#                 FROM acts
#             )
#             AND id NOT BETWEEN %s AND %s
#             LIMIT 500
#         )
#         SELECT a1.user_id, a2.user_id
#         FROM acts a1
#         JOIN acts a2 ON a1.id < a2.id
#         AND a1.user_id != a2.user_id
#         JOIN batch_track_points p1 ON p1.activity_id = a1.id
#         JOIN track_points_of_interest p2 ON p1.id < p2.id
#         AND p1.activity_id != p2.activity_id
#         AND ABS(TIME_TO_SEC(TIMEDIFF(p1.datetime, p2.datetime))) <= 30
#         AND ST_Distance_Sphere(p1.geom, p2.geom) <= 50
#
# Query Finished
# Empty DataFrame
# Columns: [user_id, user_id]
# Index: []
